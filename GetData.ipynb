# %% [markdown]
# # Preparing Dataset

# %% [markdown]
# ## Download data

# %%
# Linux Logs 2004
# !wget http://log-sharing.dreamhosters.com/hnet-hon-10122004-var.tar.bz2
# Out:
# --2020-09-26 16:37:55--  http://log-sharing.dreamhosters.com/hnet-hon-10122004-var.tar.bz2
# Resolving log-sharing.dreamhosters.com (log-sharing.dreamhosters.com)... 208.113.172.207
# Connecting to log-sharing.dreamhosters.com (log-sharing.dreamhosters.com)|208.113.172.207|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://log-sharing.dreamhosters.com/hnet-hon-10122004-var.tar.bz2 [following]
# --2020-09-26 16:37:55--  https://log-sharing.dreamhosters.com/hnet-hon-10122004-var.tar.bz2
# Connecting to log-sharing.dreamhosters.com (log-sharing.dreamhosters.com)|208.113.172.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43307575 (41M) [application/x-tar]
# Saving to: ‘hnet-hon-10122004-var.tar.bz2’
#
# 100%[======================================>] 43,307,575  33.4MB/s   in 1.2s
#
# 2020-09-26 16:37:56 (33.4 MB/s) - ‘hnet-hon-10122004-var.tar.bz2’ saved [43307575/43307575]

# %%
# Linux Logs 2005
# !wget http://log-sharing.dreamhosters.com/hnet-hon-var-log-08302005.tar.bz2
# Linux Logs 2006
# !wget http://log-sharing.dreamhosters.com/hnet-hon-var-log-02282006.tgz
# Out:
# --2020-09-26 19:42:32--  http://log-sharing.dreamhosters.com/hnet-hon-var-log-08302005.tar.bz2
# Resolving log-sharing.dreamhosters.com (log-sharing.dreamhosters.com)... 208.113.172.207
# Connecting to log-sharing.dreamhosters.com (log-sharing.dreamhosters.com)|208.113.172.207|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://log-sharing.dreamhosters.com/hnet-hon-var-log-08302005.tar.bz2 [following]
# --2020-09-26 19:42:32--  https://log-sharing.dreamhosters.com/hnet-hon-var-log-08302005.tar.bz2
# Connecting to log-sharing.dreamhosters.com (log-sharing.dreamhosters.com)|208.113.172.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9898235 (9.4M) [application/x-tar]
# Saving to: ‘hnet-hon-var-log-08302005.tar.bz2’
#
# 100%[======================================>] 9,898,235   27.8MB/s   in 0.3s
#
# 2020-09-26 19:42:32 (27.8 MB/s) - ‘hnet-hon-var-log-08302005.tar.bz2’ saved [9898235/9898235]
#
# ...

# %%
# Apache access log
# !wget http://www.almhuette-raith.at/apache-log/access.log
# !mv access.log data/apache/access.log
# Out:
# --2020-09-26 20:22:57--  http://www.almhuette-raith.at/apache-log/access.log
# Resolving www.almhuette-raith.at (www.almhuette-raith.at)... 91.143.107.26
# Connecting to www.almhuette-raith.at (www.almhuette-raith.at)|91.143.107.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1220960428 (1.1G) [text/plain]
# Saving to: ‘access.log’
#
# 100%[====================================>] 1,220,960,428 4.79MB/s   in 3m 48s
#
# 2020-09-26 20:26:45 (5.11 MB/s) - ‘access.log’ saved [1220960428/1220960428]

# %%
# Apache error log
# !wget https://zenodo.org/record/3227177/files/Apache.tar.gz?download=1
# Out:
# --2020-09-26 19:48:57--  https://zenodo.org/record/3227177/files/Apache.tar.gz?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.117.155
# Connecting to zenodo.org (zenodo.org)|188.184.117.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262905 (257K) [application/octet-stream]
# Saving to: ‘Apache.tar.gz?download=1’
#
# 100%[======================================>] 262,905      693KB/s   in 0.4s
#
# 2020-09-26 19:48:58 (693 KB/s) - ‘Apache.tar.gz?download=1’ saved [262905/262905]

# %%
# Spark logs
# !wget https://zenodo.org/record/3227177/files/Spark.tar.gz?download=1
# Out:
# --2020-09-26 19:21:48--  https://zenodo.org/record/3227177/files/Spark.tar.gz?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.117.155
# Connecting to zenodo.org (zenodo.org)|188.184.117.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 183474743 (175M) [application/octet-stream]
# Saving to: ‘Spark.tar.gz?download=1’
#
# 100%[======================================>] 183,474,743 16.2MB/s   in 12s
#
# 2020-09-26 19:22:00 (15.1 MB/s) - ‘Spark.tar.gz?download=1’ saved [183474743/183474743]

# %%
# More data on https://www.sec.gov/dera/data/edgar-log-file-data-set.html

# %%
# !wget https://github.com/lukes/ISO-3166-Countries-with-Regional-Codes/raw/master/all/all.csv -P iplocation/country_code_mapping.csv

# %% [markdown]
# ## Extract Data

# %%
# !tar -xjf hnet-hon-10122004-var.tar.bz2 -C data/
# !mv data/var data/linux_2004

# %%
# !tar -xjf hnet-hon-var-log-08302005.tar.bz2 -C data/
# !mv data/var data/linux_2005

# %%
# !tar -xzf hnet-hon-var-log-02282006.tgz -C data/
# !mv data/var data/linux_2006

# %%
# !mkdir data/apache
# !tar -xzf Apache.tar.gz?download=1 -C data/apache

# %%
# !mkdir data/spark
# !tar -xzf Spark.tar.gz?download=1 -C data/spark/

# %% [markdown]
# ## Remove non-log files

# %%
import os
import shutil

def change(action, name, exc):
    os.chmod(name, 16877)
    if os.path.isdir(name):
        for p, dirs, files in os.walk(name):
            for d in dirs:
                os.chmod(f"{p}/{d}", 16877)
            for f in files:
                os.chmod(f"{p}/{f}", 16877)
        os.rmdir(name)
    else:
        os.remove(name)

def remove_nonlog(folder):
    dirs = shutil.os.listdir(folder)
    for p, dirs, files in os.walk(folder):
        path = f"{p}/"
        if "httpd" not in i:
            if os.path.isdir(f"{folder}/{i}"):
                shutil.rmtree(f"{folder}/{i}", onerror=change)
            else:
                os.chmod(f"{folder}/{i}", 16877)
                os.remove(f"{folder}/{i}")

# %%
remove_nonlog("data/linux_2005")

# %% [markdown]
# # RnD

# %%
f = open("data/linux_2004/log/httpd/access_log", 'rb')

# %%
lines = f.readlines()

# %%
lines
# Out:
# [b'193.254.154.134 - - [10/Oct/2004:04:20:13 -0400] "GET /M83A HTTP/1.0" 404 276 "-" "-"\n',
#  b'193.254.154.134 - - [10/Oct/2004:04:31:02 -0400] "GET /M83A HTTP/1.0" 404 276 "-" "-"\n',
#  b'67.20.147.88 - - [10/Oct/2004:04:56:04 -0400] "GET / HTTP/1.1" 200 2890 "-" "Mozilla/4.0 (compatible; MSIE 5.5; Windows 98)"\n',
#  b'193.254.154.134 - - [10/Oct/2004:05:09:05 -0400] "GET /M83A HTTP/1.0" 404 276 "-" "-"\n',
#  b'63.126.25.230 - - [10/Oct/2004:05:26:53 -0400] "OPTIONS / HTTP/1.1" 200 - "-" "Microsoft-WebDAV-MiniRedir/5.1.2600"\n',
#  b'211.119.28.73 - - [10/Oct/2004:05:32:09 -0400] "GET / HTTP/1.1" 200 2890 "-" "Mozilla/5.0 (Windows; U; Windows NT 5.0; en-US; rv:1.7) Gecko/20040707 Firefox/0.9.2"\n',
#  b'193.254.154.134 - - [10/Oct/2004:05:55:14 -0400] "GET /M83A HTTP/1.0" 404 276 "-" "-"\n',
#  b'193.254.154.134 - - [10/Oct/2004:06:11:35 -0400] "GET /M83A HTTP/1.0" 404 276 "-" "-"\n',
# ...

# %%
f.close()

# %%
f1 = open("./var/log/sa/sa11", 'rb')

# %%
f.readline()
# Out:
# b'172.185.151.53 - - [01/Aug/2004:08:02:40 -0400] "GET /scripts/..%c1%1c../winnt/system32/cmd.exe?/c+dir HTTP/1.0" 404 309 "-" "-"\n'

# %%
f1.close()

# %% [markdown]
# # GET IP Location

# %%
f"https://ipinfo.io/{ip}/json"

f"https://geolocation-db.com/json/{ip}"

https://www.ip2location.com/developers/python

# %% [markdown]
# # RE Pattern RnD

# %%
import re

# %%
ua_pattern = r'(.+?)/(\S+)\s?(\(.+\))?\s?(.+)?'

# %%
re.match(ua_pattern, 'Mozilla/4.0 (compatible; MSIE 5.5; Windows 98)').groups()
# Out:
# ('Mozilla', '4.0', '(compatible; MSIE 5.5; Windows 98)', None)

# %%
re.match(ua_pattern, 'Microsoft-WebDAV-MiniRedir/5.1.2600').groups()
# Out:
# ('Microsoft-WebDAV-MiniRedir', '5.1.2600', None, None)

# %%
re.match(ua_pattern, 'Mozilla/5.0 (Windows; U; Windows NT 5.0; en-US; rv:1.7) Gecko/20040707 Firefox/0.9.2').groups()
# Out:
# ('Mozilla',
#  '5.0',
#  '(Windows; U; Windows NT 5.0; en-US; rv:1.7)',
#  'Gecko/20040707 Firefox/0.9.2')

# %%
import time

# %%
time.strptime('11/Oct/2004:07:11:13 -0400', '%d/%b/%Y:%H:%M:%S %z')
# Out:
# time.struct_time(tm_year=2004, tm_mon=10, tm_mday=11, tm_hour=7, tm_min=11, tm_sec=13, tm_wday=0, tm_yday=285, tm_isdst=-1)

# %%
manual = pd.DataFrame.from_dict([
    {
  "ip": "200.163.13.65",
  "hostname": "200-163-13-65.bsace703.dsl.brasiltelecom.net.br",
  "city": "Nova Olímpia",
  "region": "Mato Grosso",
  "country": "BR",
  "loc": "-14.7972,-57.2881",
  "org": "AS8167 Brasil Telecom S/A - Filial Distrito Federal",
  "postal": "78370-000",
  "timezone": "America/Cuiaba",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "142.93.239.94",
  "city": "Amsterdam",
  "region": "North Holland",
  "country": "NL",
  "loc": "52.3740,4.8897",
  "org": "AS14061 DigitalOcean, LLC",
  "postal": "1012",
  "timezone": "Europe/Amsterdam",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "218.2.191.31",
  "city": "Nanjing",
  "region": "Jiangsu",
  "country": "CN",
  "loc": "32.0617,118.7778",
  "org": "AS4134 CHINANET-BACKBONE",
  "timezone": "Asia/Shanghai",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "194.54.152.8",
  "city": "Simferopol",
  "region": "Crimea",
  "country": "UA",
  "loc": "44.9572,34.1108",
  "org": "AS8654 Crimeainfocom Ltd",
  "postal": "52413",
  "timezone": "Europe/Simferopol",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "66.102.9.31",
  "hostname": "google-proxy-66-102-9-31.google.com",
  "city": "Ashburn",
  "region": "Virginia",
  "country": "US",
  "loc": "39.0437,-77.4875",
  "org": "AS15169 Google LLC",
  "postal": "20149",
  "timezone": "America/New_York",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "62.117.154.141",
  "hostname": "62.117.154.141.dyn.user.ono.com",
  "city": "Vecindario",
  "region": "Canary Islands",
  "country": "ES",
  "loc": "27.8464,-15.4445",
  "org": "AS12430 VODAFONE ESPANA S.A.U.",
  "postal": "35110",
  "timezone": "Atlantic/Canary",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "85.26.165.151",
  "city": "Samara",
  "region": "Samara Oblast",
  "country": "RU",
  "loc": "53.2001,50.1500",
  "org": "AS31133 PJSC MegaFon",
  "postal": "446393",
  "timezone": "Europe/Samara",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "128.69.19.250",
  "hostname": "128-69-19-250.broadband.corbina.ru",
  "city": "Ulyanovsk",
  "region": "Ulyanovsk",
  "country": "RU",
  "loc": "54.3282,48.3866",
  "org": "AS8402 PJSC Vimpelcom",
  "postal": "432000",
  "timezone": "Europe/Ulyanovsk",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "90.151.94.131",
  "city": "Tyumen",
  "region": "Tyumen’ Oblast",
  "country": "RU",
  "loc": "57.1522,65.5272",
  "org": "AS12389 PJSC Rostelecom",
  "postal": "625000",
  "timezone": "Asia/Yekaterinburg",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "109.225.31.60",
  "hostname": "60.net-94.242.31.kaluga.ru",
  "city": "Obninsk",
  "region": "Kaluga",
  "country": "RU",
  "loc": "55.0968,36.6101",
  "org": "AS12389 PJSC Rostelecom",
  "postal": "249030",
  "timezone": "Europe/Moscow",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "23.254.49.21",
  "hostname": "21.49.254.23.in-addr.arpa",
  "city": "Piscataway",
  "region": "New Jersey",
  "country": "US",
  "loc": "40.4993,-74.3990",
  "org": "AS55286 B2 Net Solutions Inc.",
  "postal": "08854",
  "timezone": "America/New_York",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "54.189.60.10",
  "hostname": "ec2-54-189-60-10.us-west-2.compute.amazonaws.com",
  "city": "Portland",
  "region": "Oregon",
  "country": "US",
  "loc": "45.5235,-122.6762",
  "org": "AS16509 Amazon.com, Inc.",
  "postal": "97269",
  "timezone": "America/Los_Angeles",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "217.216.115.198.dyn.user.ono.com",
  "hostname": "217.216.115.198.dyn.user.ono.com",
  "city": "Cadiz",
  "region": "Andalusia",
  "country": "ES",
  "loc": "36.5267,-6.2891",
  "org": "AS12357 VODAFONE ESPANA S.A.U.",
  "postal": "11001",
  "timezone": "Europe/Madrid",
  "readme": "https://ipinfo.io/missingauth"
},
    {
  "ip": "pcp740115pcs.reston01.va.comcast.net",
  "hostname": "217.216.115.198.dyn.user.ono.com",
  "city": "Vijayawada",
  "region": "Andhra Pradesh",
  "country": "IN",
  "loc": "16.5167,80.6167",
  "org": "AS24309 Atria Convergence Technologies Pvt. Ltd. Broadband Internet Service Provider INDIA",
  "postal": "520001",
  "timezone": "Asia/Kolkata"
    }
    
])

# %% [markdown]
# ### Lookup Location from IP

# %%
count_success = 0
count_429 = 0
status_codes = []

# %%
locations = open('locations.json', 'a')

# %%
def get(ip):
    global count_success, count_429, status_codes
    resp = requests.get(f"https://geolocation-db.com/json/{ip}")
    if resp.status_code == 200:
        cont = resp.json()
        locations.write(json.dumps(cont)+"\n")
        count_success += 1
        return (ip, cont.get("region"), cont.get("country"), cont.get("city"), cont.get("timezone"))
    elif resp.status_code == 429:
        count_429 += 1
    else:
        status_codes.append(resp.status_code)
    return (None, None, None, None, None)

# %%
ips_pdf.IP = ips_pdf.IP[::-1].reset_index(drop=True)

# %%
# %%time
locations_pdf = ips_pdf.IP.apply(get)

# %%
locations.close()
